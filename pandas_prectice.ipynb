# %% [markdown]
# <a href="https://colab.research.google.com/github/sahil-plutus/ML_prectice/blob/main/pandas_prectice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([0, 10])
ypoints = np.array([0, 20])

# %%
plt.plot(xpoints, ypoints)
plt.show()

# %%
x = np.array([1,2,6,7])
y = np.array([5,3,8,4])

plt.plot(x, y)
plt.show()

# %%
y = np.array([3, 8, 1, 10, 5, 7])
plt.plot(y)
plt.show()

# %%
ypoint = np.array([3,6,1,10])

plt.plot(ypoint, marker='*')

# %%
y1 = np.array([2,4,6,8])
y2 = np.array([1,3,5,7])

plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = np.random.normal(170,10,250)
plt.hist(x)
plt.show()
